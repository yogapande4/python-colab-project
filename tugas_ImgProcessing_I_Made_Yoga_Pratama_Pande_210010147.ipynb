# %% [markdown]
# <a href="https://colab.research.google.com/github/yogapande4/python-colab-project/blob/main/tugas_ImgProcessing_I_Made_Yoga_Pratama_Pande_210010147.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar dalam mode greyscale
img = cv2.imread('/content/grayscale_image.jpg')

# Menampilkan gambar asli
plt.imshow(img)
plt.title('Gambar Asli')
plt.axis('off')
plt.show()

# menampilkan histogram
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Histogram Asli')
plt.xlabel('Intensitas Piksel')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-5-84f63e58131d>:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0, 256])

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar dalam mode greyscale
img = cv2.imread('/content/grayscale_image_brightness.jpg')

# Menampilkan gambar asli
plt.imshow(img)
plt.title('Gambar brightness up')
plt.axis('off')
plt.show()

# menampilkan histogram
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Histogram Brightness Up')
plt.xlabel('Intensitas Piksel')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-14-6387f34714c2>:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0, 256])

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar dalam mode greyscale
img = cv2.imread('/content/grayscale_image_brightness_low.jpg')

# Menampilkan gambar asli
plt.imshow(img)
plt.title('Gambar brightness low')
plt.axis('off')
plt.show()

# menampilkan histogram
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Brightness Low')
plt.xlabel('Intensitas Piksel')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-15-5d5354c9d542>:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0, 256])

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar dalam mode greyscale
img = cv2.imread('/content/grayscale_image_contrast.jpg')

# Menampilkan gambar asli
plt.imshow(img)
plt.title('Gambar Contrast Up')
plt.axis('off')
plt.show()

# menampilkan histogram
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Histogram Contrast Up')
plt.xlabel('Intensitas Piksel')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-16-c239ec742de9>:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0, 256])

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar dalam mode greyscale
img = cv2.imread('/content/grayscale_image_contrast_low.jpg')

# Menampilkan gambar asli
plt.imshow(img)
plt.title('Gambar contrast low')
plt.axis('off')
plt.show()

# menampilkan histogram
plt.hist(img.ravel(), 256, [0, 256])
plt.title('Histogram Contrast Low')
plt.xlabel('Intensitas Piksel')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-17-a3c85a80ad68>:15: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0, 256])
